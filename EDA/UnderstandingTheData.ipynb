# %%
# import the necessary libraries
import pandas as pd

# %%
# Read the data file
df = pd.read_csv("file_path.csv")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\m'
# <>:2: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\mishr\AppData\Local\Temp\ipykernel_5744\1020179195.py:2: SyntaxWarning: invalid escape sequence '\m'
#   df = pd.read_csv("C:\machine-learning-playground\Data\\train.csv")

# %% [markdown]
# ## 1. How big is the Data ?

# %%
# Use df.shape to quickly see the number of rows and columns to understand the scale of the data.
df.shape
# Out:
# (891, 12)

# %% [markdown]
# ## 2. How Data looks like ??

# %%
#  Use df.head() to look at the first few rows, or df.sample() to take a random sample to avoid bias from sorted data.
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 764          765         0       3          Eklund, Mr. Hans Linus  male
# 602          603         0       1       Harrington, Mr. Charles H  male
# 27            28         0       1  Fortune, Mr. Charles Alexander  male
# 766          767         0       1       Brewe, Dr. Arthur Jackson  male
# 236          237         0       2               Hold, Mr. Stephen  male
#
#       Age  SibSp  Parch  Ticket     Fare        Cabin Embarked
# 764  16.0      0      0  347074    7.775          NaN        S
# 602   NaN      0      0  113796   42.400          NaN        S
# 27   19.0      3      2   19950  263.000  C23 C25 C27        S
# 766   NaN      0      0  112379   39.600          NaN        C
# 236  44.0      1      0   26707   26.000          NaN        S

# %% [markdown]
# ## 3. Data type of columns

# %%
#  Use df.info() to see the data types of each column (numerical, object/string) and memory usage. 
#  This helps identify columns needing type conversion.
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %% [markdown]
# ## 4. Missing values

# %%
# Use df.isnull().sum() to get the exact count of missing values per column, which informs your cleaning strategy.
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## 5. Mathematical summary

# %%
# Use df.describe() to get statistical insights (mean, standard deviation, min, max, quartiles) for numerical columns.
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## 6. Duplicate values

# %%
#  Use df.duplicated().sum() to check if any rows are repeated.
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 7. Correlation between columns

# %%
df.corr(numeric_only=True)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
df.corr(numeric_only=True)['Survived']
# Out:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Name: Survived, dtype: float64
